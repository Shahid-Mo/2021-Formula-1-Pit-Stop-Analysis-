# %%
import numpy as np
import pandas as pd

# %%
test=pd.read_csv('results.csv')
print(test.shape)
test.head()
# Out:
# (25840, 18)
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
test=test[(test['raceId']>1050)&(test['raceId']<1074)]
test.shape
# Out:
# (440, 18)

# %%
unique_rows_drivers = test.drop_duplicates(subset='driverId')
unique_rows_drivers.shape
# Out:
# (21, 18)

# %%
drivers_2021=unique_rows_drivers['driverId']
len(drivers_2021)
# Out:
# 21

# %%
drivers=pd.read_csv('drivers.csv')
drivers.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
filtered_drivers = drivers[drivers['driverId'].isin(drivers_2021)]
filtered_drivers
# Out:
#      driverId        driverRef number code   forename     surname         dob  \
# 0           1         hamilton     44  HAM      Lewis    Hamilton  1985-01-07
# 3           4           alonso     14  ALO   Fernando      Alonso  1981-07-29
# 7           8        raikkonen      7  RAI       Kimi   Räikkönen  1979-10-17
# 8           9           kubica     88  KUB     Robert      Kubica  1984-12-07
# 19         20           vettel      5  VET  Sebastian      Vettel  1987-07-03
# 452       842            gasly     10  GAS     Pierre       Gasly  1996-02-07
# 814       815            perez     11  PER     Sergio       Pérez  1990-01-26
# 816       817        ricciardo      3  RIC     Daniel   Ricciardo  1989-07-01
# 821       822           bottas     77  BOT   Valtteri      Bottas  1989-08-28
# 829       830   max_verstappen     33  VER        Max  Verstappen  1997-09-30
# 831       832            sainz     55  SAI     Carlos       Sainz  1994-09-01
# ...

# %%
test
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 24960     24966    1052         1            131     44     2        1
# 24961     24967    1052       830              9     33     1        2
# 24962     24968    1052       822            131     77     3        3
# 24963     24969    1052       846              1      4     7        4
# 24964     24970    1052       815              9     11     0        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25395     25401    1073       849              3      6    16       \N
# 25396     25402    1073       841             51     99    14       \N
# 25397     25403    1073       847              3     63    17       \N
# 25398     25404    1073         8             51      7    18       \N
# 25399     25405    1073       853            210      9    20       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
unique_rows_const = test.drop_duplicates(subset='constructorId')
unique_rows_const.shape
# Out:
# (10, 18)

# %%
const_2021=unique_rows_const['constructorId']
len(const_2021)
const_2021
# Out:
# 24960    131
# 24961      9
# 24963      1
# 24965      6
# 24968    213
# 24969    117
# 24970     51
# 24972    214
# 24973      3
# 24975    210
# Name: constructorId, dtype: int64

# %%
teams=pd.read_csv('constructors.csv')
print(teams.shape)
teams.head()
# Out:
# (211, 5)
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
filtered_teams = teams[teams['constructorId'].isin(const_2021)]
filtered_teams
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 2                3       williams        Williams     British
# 5                6        ferrari         Ferrari     Italian
# 8                9       red_bull        Red Bull    Austrian
# 49              51           alfa      Alfa Romeo       Swiss
# 115            117   aston_martin    Aston Martin     British
# 129            131       mercedes        Mercedes      German
# 207            210           haas    Haas F1 Team    American
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 2    http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 5        http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 8         http://en.wikipedia.org/wiki/Red_Bull_Racing
# ...

# %%
unique_rows_drivers
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 24960     24966    1052         1            131     44     2        1
# 24961     24967    1052       830              9     33     1        2
# 24962     24968    1052       822            131     77     3        3
# 24963     24969    1052       846              1      4     7        4
# 24964     24970    1052       815              9     11     0        5
# 24965     24971    1052       844              6     16     4        6
# 24966     24972    1052       817              1      3     6        7
# 24967     24973    1052       832              6     55     8        8
# 24968     24974    1052       852            213     22    13        9
# 24969     24975    1052       840            117     18    10       10
# 24970     24976    1052         8             51      7    14       11
# 24971     24977    1052       841             51     99    12       12
# ...

# %%
columns_to_keep = ['raceId', 'driverId', 'constructorId']

# %%
drivers_teams=unique_rows_drivers[columns_to_keep]

# %%
megred_1=pd.merge(drivers_teams,filtered_drivers,on='driverId')
megred_1
# Out:
#     raceId  driverId  constructorId        driverRef number code   forename  \
# 0     1052         1            131         hamilton     44  HAM      Lewis
# 1     1052       830              9   max_verstappen     33  VER        Max
# 2     1052       822            131           bottas     77  BOT   Valtteri
# 3     1052       846              1           norris      4  NOR      Lando
# 4     1052       815              9            perez     11  PER     Sergio
# 5     1052       844              6          leclerc     16  LEC    Charles
# 6     1052       817              1        ricciardo      3  RIC     Daniel
# 7     1052       832              6            sainz     55  SAI     Carlos
# 8     1052       852            213          tsunoda     22  TSU       Yuki
# 9     1052       840            117           stroll     18  STR      Lance
# 10    1052         8             51        raikkonen      7  RAI       Kimi
# ...

# %%
megred_2=pd.merge(megred_1,filtered_teams,on='constructorId')
megred_2
# Out:
#     raceId  driverId  constructorId        driverRef number code   forename  \
# 0     1052         1            131         hamilton     44  HAM      Lewis
# 1     1052       822            131           bottas     77  BOT   Valtteri
# 2     1052       830              9   max_verstappen     33  VER        Max
# 3     1052       815              9            perez     11  PER     Sergio
# 4     1052       846              1           norris      4  NOR      Lando
# 5     1052       817              1        ricciardo      3  RIC     Daniel
# 6     1052       844              6          leclerc     16  LEC    Charles
# 7     1052       832              6            sainz     55  SAI     Carlos
# 8     1052       852            213          tsunoda     22  TSU       Yuki
# 9     1052       842            213            gasly     10  GAS     Pierre
# 10    1052       840            117           stroll     18  STR      Lance
# ...

# %%
columns_to_keep = ['raceId', 'driverId', 'constructorId','driverRef','code','name']
final=megred_2[columns_to_keep]

# %%
final
# Out:
#     raceId  driverId  constructorId        driverRef code            name
# 0     1052         1            131         hamilton  HAM        Mercedes
# 1     1052       822            131           bottas  BOT        Mercedes
# 2     1052       830              9   max_verstappen  VER        Red Bull
# 3     1052       815              9            perez  PER        Red Bull
# 4     1052       846              1           norris  NOR         McLaren
# 5     1052       817              1        ricciardo  RIC         McLaren
# 6     1052       844              6          leclerc  LEC         Ferrari
# 7     1052       832              6            sainz  SAI         Ferrari
# 8     1052       852            213          tsunoda  TSU      AlphaTauri
# 9     1052       842            213            gasly  GAS      AlphaTauri
# 10    1052       840            117           stroll  STR    Aston Martin
# 11    1052        20            117           vettel  VET    Aston Martin
# ...

# %%
df=pd.read_csv('pit_stops.csv')
df
# Out:
#       raceId  driverId  stop  lap      time duration  milliseconds
# 0        841       153     1    1  17:05:23   26.898         26898
# 1        841        30     1    1  17:05:52   25.021         25021
# 2        841        17     1   11  17:20:48   23.426         23426
# 3        841         4     1   12  17:22:34   23.251         23251
# 4        841        13     1   13  17:24:10   23.842         23842
# ...      ...       ...   ...  ...       ...      ...           ...
# 9629    1096       849     2   38  18:02:50   25.174         25174
# 9630    1096       840     2   40  18:04:44   21.802         21802
# 9631    1096       839     2   41  18:06:09   21.734         21734
# 9632    1096       846     2   42  18:07:36   21.559         21559
# 9633    1096       855     2   44  18:11:10   23.159         23159
#
# [9634 rows x 7 columns]

# %%
df[df['raceId']==1063]
# Out:
# Empty DataFrame
# Columns: [raceId, driverId, stop, lap, time, duration, milliseconds]
# Index: []

# %%
df2=pd.read_csv('races.csv')
df2.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# ...

# %%
temp2=df2[df2['year']==2021]
temp2
# Out:
#       raceId  year  round  circuitId                       name        date  \
# 1035    1053  2021      2         21  Emilia Romagna Grand Prix  2021-04-18
# 1037    1052  2021      1          3         Bahrain Grand Prix  2021-03-28
# 1038    1051  2021     20         78           Qatar Grand Prix  2021-11-21
# 1039    1054  2021      3         75      Portuguese Grand Prix  2021-05-02
# 1040    1055  2021      4          4         Spanish Grand Prix  2021-05-09
# 1041    1056  2021      5          6          Monaco Grand Prix  2021-05-23
# 1042    1057  2021      6         73      Azerbaijan Grand Prix  2021-06-06
# 1043    1058  2021      8         70         Styrian Grand Prix  2021-06-27
# 1044    1059  2021      7         34          French Grand Prix  2021-06-20
# 1045    1060  2021      9         70        Austrian Grand Prix  2021-07-04
# 1046    1061  2021     10          9         British Grand Prix  2021-07-18
# ...

# %%
df3=df[(df['raceId']>1050)&(df['raceId']<1074)]

# %%
df3['raceId'].unique()
# Out:
# array([1052, 1053, 1054, 1055, 1056, 1057, 1059, 1058, 1060, 1061, 1062,
#        1064, 1065, 1066, 1067, 1069, 1070, 1071, 1051, 1072, 1073],
#       dtype=int64)

# %%
before=[ 1054, 1055, 1056, 1057, 1059, 1058, 1060, 1061, 1062]
after=[ 1066, 1067, 1069, 1070, 1071, 1051, 1072, 1073]

# %%
print(len(before))
print(len(after))
# Out:
# 9
# 10

# %%
df3
# Out:
#       raceId  driverId  stop  lap      time duration  milliseconds
# 8030    1052       815     1    2  18:11:56   23.993         23993
# 8031    1052       842     1    4  18:16:14   38.338         38338
# 8032    1052         4     1   11  18:27:32   24.373         24373
# 8033    1052       846     1   12  18:29:05   24.899         24899
# 8034    1052       844     1   12  18:29:06   24.925         24925
# ...      ...       ...   ...  ...       ...      ...           ...
# 8823    1073       840     2   52  18:22:55   22.661         22661
# 8824    1073       815     3   53  18:23:09   21.385         21385
# 8825    1073       854     2   52  18:23:42   22.070         22070
# 8826    1073       852     2   53  18:24:01   21.909         21909
# 8827    1073       842     2   54  18:25:56   21.920         21920
#
# [798 rows x 7 columns]

# %%
temp=df3[df3['raceId']==1052]
df4=pd.merge(temp,final,on='driverId')
df4
# Out:
#     raceId_x  driverId  stop  lap      time duration  milliseconds  raceId_y  \
# 0       1052       815     1    2  18:11:56   23.993         23993      1052
# 1       1052       815     2   19  18:40:35   24.105         24105      1052
# 2       1052       815     3   38  19:11:20   24.191         24191      1052
# 3       1052       842     1    4  18:16:14   38.338         38338      1052
# 4       1052       842     2   19  18:41:17   24.317         24317      1052
# 5       1052       842     3   39  19:13:55   24.983         24983      1052
# 6       1052         4     1   11  18:27:32   24.373         24373      1052
# 7       1052         4     2   29  18:57:13   24.775         24775      1052
# 8       1052       846     1   12  18:29:05   24.899         24899      1052
# 9       1052       846     2   33  19:03:11   25.640         25640      1052
# 10      1052       844     1   12  18:29:06   24.925         24925      1052
# ...

# %%
pivot_table = df4.pivot_table(index='raceId_x',columns='name', values='milliseconds', aggfunc='mean')
pivot_table
# Out:
# name      Alfa Romeo  AlphaTauri  Alpine F1 Team  Aston Martin   Ferrari  \
# raceId_x
# 1052         26093.5     27402.4        24711.25  25011.666667  24448.75
#
# name      Haas F1 Team  McLaren  Mercedes  Red Bull  Williams
# raceId_x
# 1052           25570.5  24970.5   26128.0   24180.8   24724.5

# %%
temp=df3[df3['raceId']==1053]
df4=pd.merge(temp,final,on='driverId')
df4=df4[df4['milliseconds']<40_000]
df4
# Out:
#     raceId_x  driverId  stop  lap      time duration  milliseconds  raceId_y  \
# 0       1053       839     1    1  15:05:16   30.866         30866      1052
# 1       1053       839     2   27  15:49:42   30.652         30652      1052
# 2       1053       839     3   31  15:56:23   30.701         30701      1052
# 5       1053        20     1    3  15:10:09   32.024         32024      1052
# 6       1053        20     2   20  15:39:11   31.184         31184      1052
# 7       1053        20     3   22  15:42:52   39.502         39502      1052
# 11      1053       854     2   21  15:41:24   32.479         32479      1052
# 14      1053       853     1   12  15:27:20   31.168         31168      1052
# 15      1053       853     2   23  15:45:20   31.500         31500      1052
# 18      1053       842     1   14  15:30:10   31.068         31068      1052
# 19      1053       842     2   26  15:48:45   32.277         32277      1052
# ...

# %%
pivot_table2 = df4.pivot_table(index='raceId_x',columns='name', values='milliseconds', aggfunc='mean')
pivot_table2
# Out:
# name        Alfa Romeo  AlphaTauri  Alpine F1 Team  Aston Martin  Ferrari  \
# raceId_x
# 1053      30773.666667     31347.0        30770.75       33462.0  30929.0
#
# name      Haas F1 Team  McLaren      Mercedes  Red Bull  Williams
# raceId_x
# 1053      31715.666667  32497.0  33492.333333   29809.0   29983.0

# %%
final_df=pivot_table.append(pivot_table2)
# Out:
# C:\Users\mohdk\AppData\Local\Temp\ipykernel_12396\375078999.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=pivot_table.append(pivot_table2)

# %%
final_df
# Out:
# name        Alfa Romeo  AlphaTauri  Alpine F1 Team  Aston Martin   Ferrari  \
# raceId_x
# 1052      26093.500000     27402.4        24711.25  25011.666667  24448.75
# 1053      30773.666667     31347.0        30770.75  33462.000000  30929.00
#
# name      Haas F1 Team  McLaren      Mercedes  Red Bull  Williams
# raceId_x
# 1052      25570.500000  24970.5  26128.000000   24180.8   24724.5
# 1053      31715.666667  32497.0  33492.333333   29809.0   29983.0

# %%
#final_df=(final_df/10000).round(2)

# %%
final_df
# Out:
# name        Alfa Romeo  AlphaTauri  Alpine F1 Team  Aston Martin   Ferrari  \
# raceId_x
# 1052      26093.500000     27402.4        24711.25  25011.666667  24448.75
# 1053      30773.666667     31347.0        30770.75  33462.000000  30929.00
#
# name      Haas F1 Team  McLaren      Mercedes  Red Bull  Williams
# raceId_x
# 1052      25570.500000  24970.5  26128.000000   24180.8   24724.5
# 1053      31715.666667  32497.0  33492.333333   29809.0   29983.0

# %%
for i in before:
    temp=df3[df3['raceId']==i]
    df4=pd.merge(temp,final,on='driverId')
    df4=df4[df4['milliseconds']<40_000]
    #print(df4)
    pivot_table = df4.pivot_table(index='raceId_x',columns='name', values='milliseconds', aggfunc='mean')
    final_df=final_df.append(pivot_table)
# Out:
# C:\Users\mohdk\AppData\Local\Temp\ipykernel_12396\593282327.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(pivot_table)
# C:\Users\mohdk\AppData\Local\Temp\ipykernel_12396\593282327.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(pivot_table)
# C:\Users\mohdk\AppData\Local\Temp\ipykernel_12396\593282327.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(pivot_table)
# C:\Users\mohdk\AppData\Local\Temp\ipykernel_12396\593282327.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(pivot_table)
# ...

# %%
final_df
# Out:
# name        Alfa Romeo    AlphaTauri  Alpine F1 Team  Aston Martin  \
# raceId_x
# 1052      26093.500000  27402.400000    24711.250000  25011.666667
# 1053      30773.666667  31347.000000    30770.750000  33462.000000
# 1054      23961.000000  23475.666667    23343.833333  23372.500000
# 1055      22221.500000  27053.500000    22773.333333  22062.000000
# 1056      24299.000000  24429.000000    23869.000000  23921.500000
# 1057      18117.600000  17609.250000    18527.666667  17393.000000
# 1059      30956.500000  30503.500000    30747.500000  31032.500000
# 1058      21218.500000  21234.000000    21184.500000  21241.000000
# 1060      23382.333333  22790.750000    22663.000000  21197.500000
# 1061      28123.500000  28666.333333    29257.500000  28179.000000
# 1062      29659.571429  26124.000000    29952.250000  22703.000000
#
# name           Ferrari  Haas F1 Team       McLaren      Mercedes  \
# raceId_x
# 1052      24448.750000  25570.500000  24970.500000  26128.000000
# ...

# %%
final2_df=(final_df/10000).round(2)
final2_df
# Out:
# name      Alfa Romeo  AlphaTauri  Alpine F1 Team  Aston Martin  Ferrari  \
# raceId_x
# 1052            2.61        2.74            2.47          2.50     2.44
# 1053            3.08        3.13            3.08          3.35     3.09
# 1054            2.40        2.35            2.33          2.34     2.35
# 1055            2.22        2.71            2.28          2.21     2.19
# 1056            2.43        2.44            2.39          2.39     2.42
# 1057            1.81        1.76            1.85          1.74     1.75
# 1059            3.10        3.05            3.07          3.10     3.09
# 1058            2.12        2.12            2.12          2.12     2.38
# 1060            2.34        2.28            2.27          2.12     2.13
# 1061            2.81        2.87            2.93          2.82     3.30
# 1062            2.97        2.61            3.00          2.27     2.20
#
# name      Haas F1 Team  McLaren  Mercedes  Red Bull  Williams
# raceId_x
# ...

# %%
data_before=final2_df.describe()
data_before=data_before.round(2)
data_before
# Out:
# name   Alfa Romeo  AlphaTauri  Alpine F1 Team  Aston Martin  Ferrari  \
# count       11.00       11.00           11.00         11.00    11.00
# mean         2.54        2.55            2.53          2.45     2.49
# std          0.42        0.41            0.42          0.47     0.48
# min          1.81        1.76            1.85          1.74     1.75
# 25%          2.28        2.32            2.28          2.16     2.20
# 50%          2.43        2.61            2.39          2.34     2.38
# 75%          2.89        2.80            2.96          2.66     2.76
# max          3.10        3.13            3.08          3.35     3.30
#
# name   Haas F1 Team  McLaren  Mercedes  Red Bull  Williams
# count         11.00    11.00     11.00     11.00     11.00
# mean           2.57     2.57      2.48      2.45      2.57
# std            0.38     0.47      0.43      0.35      0.33
# min            2.04     1.79      1.99      1.90      2.09
# ...

# %%
data_before.iloc[1].mean()
# Out:
# 2.52

# %%
1064, 1065,

# %%
temp=df3[df3['raceId']==1064]
df4=pd.merge(temp,final,on='driverId')
df4=df4[df4['milliseconds']<40_000]
df4
# Out:
#     raceId_x  driverId  stop  lap      time duration  milliseconds  raceId_y  \
# 0       1064       854     1    4  15:08:42   35.573         35573      1052
# 1       1064       854     2   30  15:43:39   24.578         24578      1052
# 2       1064       815     1    8  15:13:52   19.287         19287      1052
# 3       1064       815     2   47  16:03:51   18.555         18555      1052
# 4       1064        20     1   10  15:16:24   18.664         18664      1052
# 5       1064        20     2   44  16:00:37   18.681         18681      1052
# 6       1064         1     1   20  15:28:18   19.770         19770      1052
# 7       1064         1     2   39  15:52:19   18.868         18868      1052
# 8       1064         1     3   70  16:30:49   19.202         19202      1052
# 9       1064       830     1   21  15:29:30   19.142         19142      1052
# 10      1064       830     2   40  15:53:30   18.578         18578      1052
# ...

# %%
pivot_table = df4.pivot_table(index='raceId_x',columns='name', values='milliseconds', aggfunc='mean')
pivot_table
# Out:
# name      Alfa Romeo  AlphaTauri  Alpine F1 Team  Aston Martin  Ferrari  \
# raceId_x
# 1064         19600.0     19506.5         19129.0  18911.333333  19908.5
#
# name      Haas F1 Team  McLaren  Mercedes  Red Bull      Williams
# raceId_x
# 1064      26716.666667  19946.0   19688.6   18890.5  21604.333333

# %%
temp=df3[df3['raceId']==1065]
df4=pd.merge(temp,final,on='driverId')
df4=df4[df4['milliseconds']<40_000]
df4
# Out:
#     raceId_x  driverId  stop  lap      time duration  milliseconds  raceId_y  \
# 0       1065       841     1    1  15:05:21   37.190         37190      1052
# 1       1065       841     2   25  15:40:55   30.551         30551      1052
# 2       1065       817     1   22  15:35:18   23.812         23812      1052
# 3       1065        20     1   22  15:35:56   25.157         25157      1052
# 4       1065        20     2   26  15:42:41   25.927         25927      1052
# 5       1065       830     1   23  15:36:46   32.456         32456      1052
# 6       1065       849     1   23  15:37:22   24.168         24168      1052
# 7       1065       854     1   23  15:37:49   24.714         24714      1052
# 8       1065       846     1   24  15:38:19   24.168         24168      1052
# 9       1065       853     1   24  15:39:22   24.928         24928      1052
# 10      1065       853     2   28  15:47:13   24.806         24806      1052
# ...

# %%
pivot_table2 = df4.pivot_table(index='raceId_x',columns='name', values='milliseconds', aggfunc='mean')
pivot_table2
# Out:
# name        Alfa Romeo  Alpine F1 Team  Aston Martin  Ferrari  Haas F1 Team  \
# raceId_x
# 1065      30747.333333         27565.0       25310.0  24420.0      26341.25
#
# name      McLaren  Mercedes  Red Bull  Williams
# raceId_x
# 1065      23990.0   24963.5   28181.0   24162.0

# %%
final_df=pivot_table.append(pivot_table2)
# Out:
# C:\Users\mohdk\AppData\Local\Temp\ipykernel_12396\375078999.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=pivot_table.append(pivot_table2)

# %%
final_df
# Out:
# name        Alfa Romeo  AlphaTauri  Alpine F1 Team  Aston Martin  Ferrari  \
# raceId_x
# 1064      19600.000000     19506.5         19129.0  18911.333333  19908.5
# 1065      30747.333333         NaN         27565.0  25310.000000  24420.0
#
# name      Haas F1 Team  McLaren  Mercedes  Red Bull      Williams
# raceId_x
# 1064      26716.666667  19946.0   19688.6   18890.5  21604.333333
# 1065      26341.250000  23990.0   24963.5   28181.0  24162.000000

# %%
for i in after:
    temp=df3[df3['raceId']==i]
    df4=pd.merge(temp,final,on='driverId')
    df4=df4[df4['milliseconds']<40_000]
    #print(df4)
    pivot_table = df4.pivot_table(index='raceId_x',columns='name', values='milliseconds', aggfunc='mean')
    final_df=final_df.append(pivot_table)
# Out:
# C:\Users\mohdk\AppData\Local\Temp\ipykernel_12396\212221273.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(pivot_table)
# C:\Users\mohdk\AppData\Local\Temp\ipykernel_12396\212221273.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(pivot_table)
# C:\Users\mohdk\AppData\Local\Temp\ipykernel_12396\212221273.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(pivot_table)
# C:\Users\mohdk\AppData\Local\Temp\ipykernel_12396\212221273.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(pivot_table)
# ...

# %%
final_df
# Out:
# name        Alfa Romeo    AlphaTauri  Alpine F1 Team  Aston Martin   Ferrari  \
# raceId_x
# 1064      19600.000000  19506.500000        19129.00  18911.333333  19908.50
# 1065      30747.333333           NaN        27565.00  25310.000000  24420.00
# 1064      19600.000000  19506.500000        19129.00  18911.333333  19908.50
# 1065      30747.333333           NaN        27565.00  25310.000000  24420.00
# 1066      31068.750000  30666.600000        31006.00  30537.000000  31472.25
# 1067      23157.000000  26319.500000        29116.00  27507.666667  25999.50
# 1069      23944.000000  23692.000000        23663.25  24027.000000  24524.00
# 1070      22314.500000  22549.000000        23542.50  23973.000000  22058.00
# 1071      20673.375000  22836.111111        20073.00  20617.857143  20543.00
# 1051      25785.250000  26018.000000        25754.00  25941.500000  25719.00
# 1072      34489.000000  27874.000000        20751.00  27165.000000  20531.00
# ...

# %%
final2_df=(final_df/10000).round(2)
final2_df
# Out:
# name      Alfa Romeo  AlphaTauri  Alpine F1 Team  Aston Martin  Ferrari  \
# raceId_x
# 1064            1.96        1.95            1.91          1.89     1.99
# 1065            3.07         NaN            2.76          2.53     2.44
# 1064            1.96        1.95            1.91          1.89     1.99
# 1065            3.07         NaN            2.76          2.53     2.44
# 1066            3.11        3.07            3.10          3.05     3.15
# 1067            2.32        2.63            2.91          2.75     2.60
# 1069            2.39        2.37            2.37          2.40     2.45
# 1070            2.23        2.25            2.35          2.40     2.21
# 1071            2.07        2.28            2.01          2.06     2.05
# 1051            2.58        2.60            2.58          2.59     2.57
# 1072            3.45        2.79            2.08          2.72     2.05
# 1073            2.23        2.21            2.15          2.21     2.19
#
# ...

# %%
data_before=final2_df.describe()
data_before=data_before.round(2)
data_before
# Out:
# name   Alfa Romeo  AlphaTauri  Alpine F1 Team  Aston Martin  Ferrari  \
# count       12.00       10.00           12.00         12.00    12.00
# mean         2.54        2.41            2.41          2.42     2.34
# std          0.51        0.36            0.41          0.35     0.34
# min          1.96        1.95            1.91          1.89     1.99
# 25%          2.19        2.22            2.06          2.17     2.05
# 50%          2.36        2.33            2.36          2.46     2.33
# 75%          3.07        2.62            2.76          2.62     2.48
# max          3.45        3.07            3.10          3.05     3.15
#
# name   Haas F1 Team  McLaren  Mercedes  Red Bull  Williams
# count         11.00    12.00     12.00     12.00     12.00
# mean           2.55     2.37      2.36      2.36      2.41
# std            0.27     0.35      0.34      0.41      0.32
# min            2.10     1.99      1.97      1.89      2.10
# ...

# %%
data_before.iloc[1].mean()
# Out:
# 2.4170000000000003
